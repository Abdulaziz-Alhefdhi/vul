# %%
import pandas as pd

data_dir = "/home/aa043/sea/gpu_data/data/vul/"
vector_type = "tfidf"

data_df_raw = pd.read_csv(data_dir+"comments_and_answers.csv")
print('(rows, columns):', data_df_raw.shape)
data_df_raw.head()
# Out:
# (rows, columns): (1264096, 11)
#    comment_id                                        commentText  \
# 0           4  // per http://www.ietf.org/rfc/rfc2109.txt bro...
# 1           4  // per http://www.ietf.org/rfc/rfc2109.txt bro...
# 2           4  // per http://www.ietf.org/rfc/rfc2109.txt bro...
# 3           4  // per http://www.ietf.org/rfc/rfc2109.txt bro...
# 4           4  // per http://www.ietf.org/rfc/rfc2109.txt bro...
#
#                                         Comment_link       detected_RFC_ID  \
# 0  https://github.com/angular/angular.js/blob/c8d...  RFC2109 (Branch_415)
# 1  https://github.com/angular/angular.js/blob/c8d...  RFC2109 (Branch_415)
# 2  https://github.com/angular/angular.js/blob/c8d...  RFC2109 (Branch_415)
# 3  https://github.com/angular/angular.js/blob/c8d...  RFC2109 (Branch_415)
# 4  https://github.com/angular/angular.js/blob/c8d...  RFC2109 (Branch_415)
#
#              rfc_series AnswerId                       SOAnswer_link  \
# ...
